# %% [markdown]
# 准确率p=51,q=49
# 画出分布函数图

# %%
p=0.51
q=0.49
x=list(range(1,501))#坐标列表

# %%
from scipy.stats import binom
import math as m
#设置实验次数N
N=500

# %%
#计算y值
def calculate_y(N,p):
    sum=[]
    temp=0
    for i in range(m.ceil(N/2),N):
#         if i>=m.ceil(N/2):
            val=binom.pmf(i,N,p)
            temp+=val
            sum.append(temp)
#         else:
#             sum.append(0)
    return sum
y=calculate_y(N,p)

# %%
#画出概率分布函数
import matplotlib.pyplot as plt
plt.plot(x[m.ceil(N/2):],y)
plt.show()
